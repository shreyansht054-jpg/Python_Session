# %% [markdown]
# # Variables

# %% [markdown]
# - Variable is use to store the value the value in a memory
#
# - the value can be changed

# %%
num1=100
# 100 stored in a variable num1
num1
# Out:
# 100

# %%
num1=200
num1
# Out:
# 200

# %%
shreyansh
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 shreyansh
#
# NameError: name 'shreyansh' is not defined

# %%
'shreyansh'
# Out:
# 'shreyansh'

# %%
n1=100    # ans  1
n2=200    # ans  2
n3=300    # ans  3
n=n1+n2+n5  # line: 4 name 'n5' is not defined

# %%
n1=100    # ans  1
n2=200    # ans  2
n3=300    # ans  3
n=n1+n2+n6  # 4 name 'n6' is not defined
n6=600
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 4
#       2 n2=200    # ans  2
#       3 n3=300    # ans  3
# ----> 4 n=n1+n2+n6  # 4 name 'n6' is not defined
#       5 n6=600
#
# NameError: name 'n6' is not defined

# %%
n1=100    # ans  1
n2=200    # ans  2
n3=300    # ans  3
n5=600
n=n1+n2+n5  # 4 name 'n4' is not defined

# %%
n1=100
n2=100

# %%
n1=100,200  # w
n1   # tuple bracket
# Out:
# (100, 200)

# %%
n1,n2=100,200
print(n1)
print(n2)
# Out:
# 100
# 200

# %%
n1,n2=100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 n1,n2=100
#
# TypeError: cannot unpack non-iterable int object

# %%
NUMBER=100  # w
number=100   # w
NUMBER=200   # w
number123=400  # w
123number =500  #f
number%one=600   # f
number_one_=700   # w
_=800  # w
sum=900  # W but not recommended
if=900  # f

# %%
number one=900
# Out:
#   Cell In[34], line 1
#     number one=900
#            ^
# SyntaxError: invalid syntax

# %%
NUMBER=100

# %%
NUMBER
# Out:
# 100

# %%
overallJusification=100

# %%
overallJusification
# Out:
# 100

# %% [markdown]
# - Variables are case sensitive
#
# - Variables can be upper case also can be lower case
#
# - Variables should not start with numbers
#
# - Variables does not include special characters
#
# - Variables can contain underscores
#
# - Variables can not a be a math inbuilt functions
#
# - Variables can not a be reserved words or keywords
