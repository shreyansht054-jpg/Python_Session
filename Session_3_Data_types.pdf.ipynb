# %%
# this file i opened from Home tab
# in home tab im in python_sessions folder

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\shreyansh tiwari\\Documents\\NareshIT\\Python_Session'

# %% [markdown]
# # in built functions

# %%
# functions always with ()
print()    
max()        
min()
sum()
len()
type()

# %% [markdown]
# - when ever you miss the brackets for function it will give indication
#
#     - it will display as **function**
#
#     - it will display as **bound method**

# %%
l=[1,2,3,4,5]

# %%
print(l)
type(l) 
max(l) 
min(l) 
len(l) 
sum(l)
# Out:
# [1, 2, 3, 4, 5]
# 15

# %%
type(l)
# Out:
# list

# %%
max(l)
# Out:
# 5

# %%
min(l)
# Out:
# 1

# %%
len(l)
# Out:
# 5

# %%
sum(l)
# Out:
# 15

# %%
name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 name
#
# NameError: name 'name' is not defined

# %%
name=100

# %%
n1=10
n2=20
n3=400
n4=n1+n2+n33
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 4
#       2 n2=20
#       3 n3=400
# ----> 4 n4=n1+n2+n33
#
# NameError: name 'n33' is not defined

# %%
print(l)
type(l) 
max(l) 
min(l) 
len(l) 
sum(l) 

# function
# bound method

# %% [markdown]
# # Data type

# %% [markdown]
# - int
# - float
# - bool
# - str
# - complex
# - range
# - list
# - tuple
# - dict
# - set
# - frozenset
# - bytearray
# - bytes
# - memoryview

# %% [markdown]
# $integer$

# %%
num=100
print(num)
# Out:
# 100

# %%
type(num)
# Out:
# int

# %% [markdown]
# $float$

# %%
money=5000.75
type(money)
# Out:
# float

# %%
money=5000.75
print(money)
# Out:
# 5000.75

# %%
1e10
# Out:
# 10000000000.0

# %%
1e1,1e2,1e3
# Out:
# (10.0, 100.0, 1000.0)

# %%
print(1e1) # 1*10
print(1e2) # 1*100
print(1e3) #1*1000
# Out:
# 10.0
# 100.0
# 1000.0

# %%
1e5 # 1*100000
# Out:
# 100000.0

# %%
100e10
# Out:
# 1000000000000.0

# %%
1e-3 # 1/1000
# Out:
# 0.001

# %%
10000000000
# Out:
# 10000000000

# %%
1e10
# Out:
# 10000000000.0

# %%
# ML many notations epower
520e-10  # 520/100000000000000=0.0000000000520
# Out:
# 5.2e-08

# %% [markdown]
# **strings**

# %%
name='python'
type(name)
# Out:
# str

# %%
name='python'
print(name)
# Out:
# python

# %%
city="hyderabed"
city
# Out:
# 'hyderabed'

# %%
# name : single quotes
# city : double quotes
name,city # by default single quotes only
# Out:
# ('python', 'hyderabed')

# %%
1e1 # 1*10
1e2 # 1*100
1e3
# Out:
# 1000.0

# %%
name,city
# Out:
# ('python', 'hyderabed')

# %%
print(name,city)
# whenerver we print the answers with out quotes
# Out:
# python hyderabed

# %% [markdown]
# ## tripe quotes
# - Tripe quotes are used to write multi lines
# - If i want to write an information, i can use **markdown** in jupyter notebook
# - But in vscoad there is no markdown
# - Then i can use triple quotes to convey the information
# - this procedure is called as **doc string**
# - in prompt engineering also

# %%
"""today im learning python data types
these are very easy"""
# Out:
# 'today im learning python data types\nthese are very easy'

# %%
- what are the inbuilt functions

print()
type()
len()
max()
min()
sum()

- function

- bound method

# %%
from sklearn.feature_selection import VarianceThreshold

# %%
VarianceThreshold()
# Out:
# VarianceThreshold()

# %%
import pandas as pd
df=pd.DataFrame([1,2,3,4,5,6])

# %%
df.head()
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %% [markdown]
# -  integer : int
#
# -  float
#
# -  string : str

# %%
9.45e-3  # 9.45/100= 0.00945
# Out:
# 0.00945

# %%
name1='city'
name2="city"
name3="""city"""    # Dok string

# %%
name,name2
# Out:
# ('python', 'city')

# %%
print(name1,name2)
# Out:
# city city

# %%
'i like 'python''    # fail
"i like "python""    # fail
# Out:
#   Cell In[44], line 1
#     'i like 'python''    # fail
#              ^
# SyntaxError: invalid syntax

# %%
str1='i like "python"'
print(str1)
# Out:
# i like "python"

# %%
str2="i like 'python'"
print(str2)
# Out:
# i like 'python'

# %%
10+20  # logic
# Out:
# 30

# %%
"python
# Out:
#   Cell In[48], line 1
#     "python
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
"python'
# Out:
#   Cell In[49], line 1
#     "python'
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
"python"    # NO error
'python'    # NE
"python     # E syntex error
"python'    # syntax error
'python"    # syntax error


n1=100
n2=200
n3=n1+n2+n333
# Out:
#   Cell In[50], line 3
#     "python     # E syntex error
#     ^
# SyntaxError: unterminated string literal (detected at line 3)

# %% [markdown]
# **boolean**

# %% [markdown]
# -  True indicates 1, ON
#
# -  False indicates 0, OFF

# %%
value=True
type(value)
# Out:
# bool

# %%
value1=False
type(value1)
# Out:
# bool

# %%
print(value)
# Out:
# True

# %%
true=100
value2=true
value2
# Out:
# 100

# %%
true=True     # true varaibale=True bool
false='False' # string
true=100
false=true    # integr
True=10       # error

# %%
true=True
type(true)
# Out:
# bool

# %%
false='False'
type(false)
# Out:
# str

# %%
true=100
false=true
type(false)
# Out:
# int

# %% [markdown]
# -  int
#
# -  float
#
# -  str
#
# -  bool
