# %%
a=10
b=20
c=a+b
c      # shift+enter
# Out:
# 30

# %%
a=10
b=20
c=a+b
print(c)
# Out:
# 30

# %%
import time
time.sleep(10)

# kernel which === idle
# kernel black ---- busy
# kernel red  ===== deab (machine restart or close
#                   the jupyternote book and open)
# when kernel is busy do not run any other cells

# %%
a=10
a
# Out:
# 10

# %%
#{}  ====== you did not run the cell
#[*] ====== you ran it kernel is busy
#[1] ====== you already ran

# %% [markdown]
# im learning python
#
# a=10a
#
# esc+m ==== > code mode to mark down
#
# esc+y ==== > mark down to code mode

# %% [markdown]
# - we develop the project
#
# - we need to create a document for client
#
# - jupyter notebook  will give flexibility
#
# - we can write the explanation of each code line
#
# - we can insert diagrams
#
# - we can insert formulae
#
# - we can write bullet points
#
# - we can create a tables
#
# - esc+m ===> shift+enter

# %% [markdown]
# # python

# %% [markdown]
# ## python

# %% [markdown]
# **python**

# %%
# import will word for some students
# import will not word for other students(luck)

# %% [markdown]
# <img id="dimg_KEHNaKnaE6-SseMPoZ7w6QQ_17" src="data:image/jpeg;base64,..." class="YQ4gaf" height="225" style="object-position:66% 0%" width="225" alt="Python (programming language) - Wikipedia" data-csiid="KEHNaKnaE6-SseMPoZ7w6QQ_5" data-atf="1">

# %% [markdown]
# <img id="dimg_dHHIaPr7NNGL4-EPiNOAqQw_409" src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRQEaeovV57e79hf86twNnk8IwJAHJPhcsjVQ&amp;s" class="YQ4gaf" height="154" style="object-position:28% 43%" width="328" alt="What is AI? - GeeksforGeeks" data-csiid="dHHIaPr7NNGL4-EPiNOAqQw_171" data-atf="4" data-ilt="1757966731502" data-deferred="3" data-iml="1757966731502">

# %%
Ctrl+A
Ctrl+C
Ctrl+V
Esc+M
Shift+Enter

# %%
num=100
# 100 is stored in a variable called as num
num
# Out:
# 100

# %%
num=100
print(num)
# Out:
# 100

# %%
n1=10
n2=20
n1
n2      # we can able to see only last answer
# Out:
# 20

# %%
n1=10
n2=20
print(n1)
print(n2)
# Out:
# 10
# 20

# %%
n1=10
n2=20
print(n1,n2)
# Out:
# 10 20

# %%
NUMBER=100
NUMBER
# Out:
# 100

# %%
number=200
number
# Out:
# 200

# %%
number,NUMBER
# Out:
# (200, 100)

# %%
NUMBER=300
NUMBER
# Out:
# 300

# %%
number123=400
number123
# Out:
# 400

# %%
123number=500
123number
# Out:
#   Cell In[11], line 1
#     123number=500
#       ^
# SyntaxError: invalid decimal literal

# %%
number%one=600
number%one
# Out:
#   Cell In[12], line 1
#     number%one=600
#     ^
# SyntaxError: cannot assign to expression here. Maybe you meant '==' instead of '='?

# %%
number_one=700
number_one
# Out:
# 700

# %%
overalljustification=800
overall_justification=900

# %%
_=900

# %%
sum=100
sum
# Out:
# 100

# %%
if=100
if
# Out:
#   Cell In[17], line 1
#     if=100
#       ^
# SyntaxError: invalid syntax

# %%
NUMBER # W
number # w
NUMBER # w
number123 # w
123number # f
number%one # f
number_one # w
_ # w
sum=100 # works but we should not use
if=400 # f

# %%
sum=900
max
min
1
2
3
# Out:
# 3

# %%
if=900
max
else
for
while
True
False

# %%
name='python'
name
# Out:
# 'python'

# %% [markdown]
# **name=python**
#
# - balck === variable
#
# - red === string
#
# - light green === math
#
# - bold === key
