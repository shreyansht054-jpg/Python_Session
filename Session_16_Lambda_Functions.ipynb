# %% [markdown]
# **lambad function**
#
# - lambda function is a function we can represnt in a single line
#
# - it behave exatcly hoe our origianl function
#
# - lambda argument: expression

# %% [markdown]
# **case:1 function with one argument**

# %%
def add(n):
    return(n+10)
add(20)
# Out:
# 30

# %%
# syntax
<function name>=lambda<arg> : <return value>
# function name : add
# arg : n
# return : n+10

# %%
add=lambda n : n+10
add
# Out:
# <function __main__.<lambda>(n)>

# %%
add(100)
# Out:
# 110

# %%
# def cube(a):
#    return(a*a*a)

# %%
cube=lambda a : a*a*a
cube(10)
# Out:
# 1000

# %% [markdown]
# **Case-2: more than one argument**

# %%
def summ(n1,n2):
    return(n1+n2)

def avg (n1,n2,n3):
    return((n1+n2+n3)/3)

def avg(a,b,c):
    return(round(a+b+c)/3)

# %%
summ=lambda n1,n2 : n1+n2
summ(20,20)
# Out:
# 40

# %%
avg=lambda n1,n2,n3=100 : ( n1+n2+n3)/3
avg(20,30,40)
# Out:
# 30.0

# %%
avg=lambda a,b,c=100 : round((a+b+c)/3,2)
avg(20,77)
# Out:
# 65.67

# %%
avg= lambda n1,n2,n3=100 : (n1+n2+n3)/3
avg(1,11)
# Out:
# 37.333333333333336

# %% [markdown]
# **case-3: if -else**

# %%
<fun name>= lambda <arg> : <expression>
<fun name>= lambda <arg1>,<arg2> : <experession>
<fun name>= lambda <arg> : <if_out> <if con> else<else_out>

# %%
even_odd= lambda i : 'even' if i%2==0 else 'odd'
even_odd
# Out:
# <function __main__.<lambda>(i)>

# %%
even_odd= lambda i : 'even' if i%2==0 else 'odd'
even_odd(21)
# Out:
# 'odd'

# %%
even_odd= lambda i : f'even_{i}' if i%2==0  else f'odd_{i}'
even_odd(21)
# Out:
# 'odd_21'

# %%
# wap take two number find greatr number using lambda

greater= lambda n1,n2 : n1 if n1>n2 else n2
greater(100,200)
# Out:
# 200

# %%
def grade(n):
    if n>=75:
        return('A')
    elif n>=60:
        return('B')
    else:
        return('C')
grade(67)
# Out:
# 'B'

# %%
Grade= lambda i: 'A' if i>=75 else\
                 'B' if i>=75 else\
                 'C'
grade(75)
# Out:
# 'A'

# %%
Grade= lambda i : ('A' if i>=75 else 
                  'B' if i>=60 else 
                  'C')
Grade(21)
# Out:
# 'C'

# %% [markdown]
# **Case-4: usage of list**

# %%
l=['hyd','bangaluru','pune','mumbai']
[i.capitalize() for i in l]
# Out:
# ['Hyd', 'Bangaluru', 'Pune', 'Mumbai']

# %%
# argument : i
# experesion : i.capitalize()
# lambda <arg> : <expression>

# %%
lambda i : l.capitalize()
f1('hey')
# Out:
# 'Hey'

# %%
def f1(i):
    return(i.capitalize())
f1('hey')
# Out:
# 'Hey'

# %% [markdown]
# **Map**

# %%
lambda i  : i.capitalize()
lambda i  : i.capitalize(),l
map(lambda i : i.capitalize(),l)

# %%
list(map(lambda i : i.capitalize(),l))
# Out:
# ['Hyd', 'Bangaluru', 'Pune', 'Mumbai']

# %%
l=['hyd','banga#luru','pune','mumbai']
[i if '#' in i else None for i in l]

# argument : i
# expression : '#' in i
# True or False is only the expression
'#' in 'mumbai'
# Out:
# False

# %%
lambda i : '#' in i
lambda i : '#' in i,l
map(lambda i : '#' in i,l)
list(map(lambda i: '#'in i,l))
# Out:
# [False, False, False, False]

# %% [markdown]
# **filter**

# %%
list(filter(lambda i: '#' in i,l))
# Out:
# ['banga#luru']

# %%
# Sir, in 'map' function why do we use 'parenthesis()' instead of 'square brackets[]' after the list

# () ==== method or fun
# [] === access the elemnets

len sum max min map filter ()

l[0]
# Out:
#   Cell In[6], line 6
#     len sum max min map filter ()
#         ^
# SyntaxError: invalid syntax

# %%
# wap get the squqre of the  element
l=[1,2,3,4] ==== output = [1,4,9,16]
# wap retrive only first letter of element
l=['hyd','bengaluru','chennai']= output = ['h','b','c']
# wap retrive the lements len of element greeter than 4
l=['hyd','bengaluru','chennai']
output=['bengaluru',chennai]

# %%
l=[1,2,3,4]
[i*i for i in l]
# arg: i expression : i*i
# Out:
# [1, 4, 9, 16]

# %%
list(map(lambda i: i*i))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 list(map(lambda i: i*i))
#
# TypeError: map() must have at least two arguments.

# %%
l=['hyd','bengaluru','chennai']
list(map(lambda i: i[0],l))
# Out:
# ['h', 'b', 'c']

# %%
l=['hyd','bengaluru','chennai']
list(filter(lambda i: len(i)>4,l))
# Out:
# ['bengaluru', 'chennai']

# %%
list(map(lambda i: i*i,l))
list(map(lambda i: i[0],l))
list(filter(lambda i: len(i)>4,l))

# lambda
#  === list comprehen
#  ======= list
# ========== string
#    =========== for
#    ============= if-else

# %% [markdown]
# **reduce**
#
# - reduce is a mathod will do all math operations with lambda func
#
# - retuce will available package called as **functools**
#
# - import functools and apply dir

# %%
# sum of first 10 natural numbers
summ=0
[summ:=summ+i for i in range(1,11)][-1]
# Out:
# 55

# %%
l=[10,20,30,40]
summ=0
[summ:=summ+i for i in (l)][-1]

# what are the arguments
# arg: i sum
# expression summ=summ+i
# Out:
# 100

# %%
summ=0
lambda summ,i : summ=summ+i  # error
# Out:
#   Cell In[13], line 2
#     lambda summ,i : summ=summ+i  # error
#     ^
# SyntaxError: cannot assign to lambda

# %%
summ=0
lambda summ,i : summi,  l
# Out:
# (<function __main__.<lambda>(summ, i)>, [10, 20, 30, 40])

# %%
summ=0
list(map(lambda summ,i : summ+i , l)) # fail
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 2
#       1 summ=0
# ----> 2 list(map(lambda summ,i : summ+i , l))
#
# TypeError: <lambda>() missing 1 required positional argument: 'i'

# %%
map   # in built
filter # in built
reduce # it is not a inbuil 
#

# %%
import functools
dir(functools)
# Out:
# ['GenericAlias',
#  'RLock',
#  'WRAPPER_ASSIGNMENTS',
#  'WRAPPER_UPDATES',
#  '_CacheInfo',
#  '_HashedSeq',
#  '_NOT_FOUND',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_c3_merge',
#  '_c3_mro',
#  '_compose_mro',
#  '_convert',
#  '_find_impl',
#  '_ge_from_gt',
#  '_ge_from_le',
#  '_ge_from_lt',
#  '_gt_from_ge',
#  '_gt_from_le',
#  '_gt_from_lt',
#  '_initial_missing',
#  '_le_from_ge',
#  '_le_from_gt',
#  '_le_from_lt',
#  '_lru_cache_wrapper',
#  '_lt_from_ge',
#  '_lt_from_gt',
#  '_lt_from_le',
#  '_make_key',
#  '_unwrap_partial',
#  '_unwrap_partialmethod',
#  'cache',
#  'cached_property',
#  'cmp_to_key',
#  'get_cache_token',
#  'lru_cache',
#  'namedtuple',
#  'partial',
#  'partialmethod',
#  'recursive_repr',
#  'reduce',
#  'singledispatch',
#  'singledispatchmethod',
#  'total_ordering',
#  'update_wrapper',
#  'wraps']

# %%
# import functools
# functools.reduce()

from functools import reduce

lambda summ,i : summ+i
lambda summ,i : summ+i,l
reduce(lambda summ,i : summ+i,l)
# Out:
# 'hydbengaluruchennai'

# %%
# import functools
# functools.reduce()

from functools import reduce

lambda summ,i : summ+i
lambda summ,i : summ+i,l
reduce(lambda summ,i : summ+i,l)
# Out:
# 100

# %%
from functools import reduce
l=[10,20,30,40]
reduce(lambda s,i : s+i,l)  # s=0 
# 0+10+20+30+40=100
# Out:
# 100

# %%
from functools import reduce
l=[10,20,30,40]
reduce(lambda s,i : s+i,l,100)  # s=0 
# 100+10+20+30+40=200
# Out:
# 200
