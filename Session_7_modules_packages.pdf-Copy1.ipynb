# %% [markdown]
# - Variables
#
# - Data types
#
# - type cast
#
# - basic codes
#
# - input and eval

# %%
# lucky is develope a python code
# addition

# i developed addition code ==== entire world
# he went anaconda organization

# MOU= who ever installed anaconda
# my python should come down load automatically
# in their Laptop

# %%
import addition
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import addition
#
# ModuleNotFoundError: No module named 'addition'

# %%
import random

# %%
import virat
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 import virat
#
# ModuleNotFoundError: No module named 'virat'

# %%
import time

# %%
import pandas

# %%
import math

# %%
import os

# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
# Lucky is ver happy
# addition
# subtraction
# multiplication
# division

addition === addition.py === module
subt     === subt.py     ===module
multi    === mult.py     === module
div      === div.py      === module

# %%
# module name: math_fun
import math_fun
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 2
#       1 # module name: math_fun
# ----> 2 import math_fun
#
# ModuleNotFoundError: No module named 'math_fun'

# %%
import random

# %%
dir(random)
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_ONE',
#  '_Sequence',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_accumulate',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_fabs',
#  '_floor',
#  '_index',
#  '_inst',
#  '_isfinite',
#  '_lgamma',
#  '_log',
#  '_log2',
#  '_os',
#  '_parse_args',
#  '_pi',
#  '_random',
#  '_repeat',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  'betavariate',
#  'binomialvariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'main',
#  'normalvariate',
#  'paretovariate',
#  'randbytes',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
# ...

# %%
# stape-1 import <module name>
import random
# stape_2 (<modulename>)
dir(random)
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_ONE',
#  '_Sequence',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_accumulate',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_fabs',
#  '_floor',
#  '_index',
#  '_inst',
#  '_isfinite',
#  '_lgamma',
#  '_log',
#  '_log2',
#  '_os',
#  '_parse_args',
#  '_pi',
#  '_random',
#  '_repeat',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  'betavariate',
#  'binomialvariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'main',
#  'normalvariate',
#  'paretovariate',
#  'randbytes',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
# ...

# %%
# module name: random
# attribute name : randint

random.randint
# Out:
# <bound method Random.randint of <random.Random object at 0x00000220AE85A6E0>>

# %%
random.virat

# uncle random does not have a kid with name virat
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 random.virat
#
# NameError: name 'random' is not defined

# %%
random.randint
# Out:
# <bound method Random.randint of <random.Random object at 0x000001FC7EA34A70>>

# %%
# stape-1: import <module name>
# stape-2: dir(<module name>)
#          directory will display all the attribute names
# stape-3: modulename. attribute
random.randint
# Out:
# <bound method Random.randint of <random.Random object at 0x000001FC7EA34A70>>

# %%
import math
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fma',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
math.pi
# Out:
# 3.141592653589793

# %%
random.randint
# Out:
# <bound method Random.randint of <random.Random object at 0x00000220AE85A6E0>>

# %%
import random
random.random
# Out:
# <function Random.random()>

# %%
dir(random)
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_ONE',
#  '_Sequence',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_accumulate',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_fabs',
#  '_floor',
#  '_index',
#  '_inst',
#  '_isfinite',
#  '_lgamma',
#  '_log',
#  '_log2',
#  '_os',
#  '_parse_args',
#  '_pi',
#  '_random',
#  '_repeat',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  'betavariate',
#  'binomialvariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'main',
#  'normalvariate',
#  'paretovariate',
#  'randbytes',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
# ...

# %%
# every attribute has one use case
# what is the use of this kid: randint

help(random.randint)
# Out:
# Help on method randint in module random:
#
# randint(a, b) method of random.Random instance
#     Return random integer in range [a, b], including both end points.

# %%
# randint(a,b)
# randint(1,10)  # a=1  b=10

random.randint(1,10)
# Out:
# 6

# %%
# step-1 import<module name>
# step-2 dir(<module name>)
# step-3 modulename.attribute name [direct vs bound]
# step-4 help(modulename.attributename)
# apply the use casr

# module name :  random
# attribute name  : randint

import random

# %%
dir(random)
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_ONE',
#  '_Sequence',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_accumulate',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_fabs',
#  '_floor',
#  '_index',
#  '_inst',
#  '_isfinite',
#  '_lgamma',
#  '_log',
#  '_log2',
#  '_os',
#  '_parse_args',
#  '_pi',
#  '_random',
#  '_repeat',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  'betavariate',
#  'binomialvariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'main',
#  'normalvariate',
#  'paretovariate',
#  'randbytes',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
# ...

# %%
random.randint   # bound method
# Out:
# <bound method Random.randint of <random.Random object at 0x000001FC7EA34A70>>

# %%
help(random.randint)
# Out:
# Help on method randint in module random:
#
# randint(a, b) method of random.Random instance
#     Return random integer in range [a, b], including both end points.

# %%
random.randint(1,10)
# Out:
# 7

# %%
# Module : random             #Module: math
#attribute: randing           #attribute: pi

# Module  : random            #Module: math
#attribute: random            #attribute: sqrt

# Module : random             #Module : math
#attribute:  uniform          #attribute: pow

# random : random             #Module : math
#attribute: choise            #attribute: e
random.choice(['Apple','Banana','Cherry','Dairymilk'])

# Module: random        #Module: math
#attribute: sample      #addribute: sin
random.sample(['Apple','Banana','Cherry','Dairymilk'])in english
ChatGPT

# %%
random.random
# Out:
# <function Random.random()>

# %%
help(random.randint)
# Out:
# Help on method randint in module random:
#
# randint(a, b) method of random.Random instance
#     Return random integer in range [a, b], including both end points.

# %%
random.random()
# Out:
# 0.9428884708167838

# %%
random.uniform
# Out:
# <bound method Random.uniform of <random.Random object at 0x00000220AE85A6E0>>

# %%
help(random.uniform)
# Out:
# Help on method uniform in module random:
#
# uniform(a, b) method of random.Random instance
#     Get a random number in the range [a, b) or [a, b] depending on rounding.
#
#     The mean (expected value) and variance of the random variable are:
#
#         E[X] = (a + b) / 2
#         Var[X] = (b - a) ** 2 / 12

# %%
#random.uniform(<shift+tab>)

random.uniform(1,10)
# Out:
# 9.143106629955932

# %%
random.randint(1,10)
# Out:
# 1

# %%
random.random()
# Out:
# 0.6060501196828731

# %%
random.uniform(1,10)
# Out:
# 2.5019649223515827

# %%
math.pi
# Out:
# 3.141592653589793

# %%
import random

# Generate a random integer between 1 and 10
print(random.randint(1, 10))
# Out:
# 8

# %%
math.e
# Out:
# 2.718281828459045

# %%
math.pow(2,3)
# Out:
# 8.0

# %%
math.sqrt(25)
# Out:
# 5.0

# %%
import random

# Generate a random float between 0 and 1
print(random.random())
# Out:
# 0.7348031626589686

# %%
import random

# Generate a random float between 5 and 10
print(random.uniform(5, 10))
# Out:
# 6.75057926993807

# %%
import random

# Pick a random item from a list
print(random.choice(['Apple', 'Banana', 'Cherry', 'Dairymilk']))
# Out:
# Banana

# %%
import random

# Pick 2 random items from a list (without replacement)
print(random.sample(['Apple', 'Banana', 'Cherry', 'Dairymilk'], 2))
# Out:
# ['Banana', 'Dairymilk']

# %%
import math

# Find the sine of 90 degrees (π/2 radians)
print(math.sin(math.pi / 2))   # Output: 1.0
# Out:
# 1.0

# %%
# inside bracket:  shift+tab 
random.randin()

# %%
random.randint(1,5)  vs  random.randint(1,56)

# %% [markdown]
# -  module not found error
#
#        - It is not installed we to install
#
# - Attribute not found in module
#
#         - we need to check by apple: dir

# %%
import cv2

# %%
# import time 
# attribute : sleep
import time

# %% [raw]
# print('hello')

# %%
time.sleep(5)
print('hello')
# Out:
# hello

# %%
# attribute: start
time.start
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 2
#       1 # attribute: start
# ----> 2 time.start
#
# AttributeError: module 'time' has no attribute 'start'

# %%
dir(time)
# Out:
# ['_STRUCT_TM_ITEMS',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'altzone',
#  'asctime',
#  'ctime',
#  'daylight',
#  'get_clock_info',
#  'gmtime',
#  'localtime',
#  'mktime',
#  'monotonic',
#  'monotonic_ns',
#  'perf_counter',
#  'perf_counter_ns',
#  'process_time',
#  'process_time_ns',
#  'sleep',
#  'strftime',
#  'strptime',
#  'struct_time',
#  'thread_time',
#  'thread_time_ns',
#  'time',
#  'time_ns',
#  'timezone',
#  'tzname']

# %%
# module name: time
# attribute name: time
time.time()
# Out:
# 1758255292.545919

# %%
start=time.time()
time.sleep(5)
end=time.time()
print(f"the time taken is :{end-start}")
# Out:
# the time taken is :5.000737905502319

# %%
# module name: keyword
# attribute: kwlist
import keyword

# %%
len(keyword.kwlist)
# Out:
# 35

# %%
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
import random
random
# Out:
# <module 'random' from 'C:\\Users\\shreyansh tiwari\\anaconda3\\Lib\\random.py'>

# %%
pip freeze
# Out:
# aiobotocore @ file:///C:/b/abs_431uzunk2v/croot/aiobotocore_1738237882529/work
# aiohappyeyeballs @ file:///C:/b/abs_e9fm5mk6ak/croot/aiohappyeyeballs_1734469429350/work
# aiohttp @ file:///C:/b/abs_d4_gdjffav/croot/aiohttp_1734687146788/work
# aioitertools @ file:///tmp/build/80754af9/aioitertools_1607109665762/work
# aiosignal @ file:///tmp/build/80754af9/aiosignal_1637843061372/work
# alabaster @ file:///C:/Users/dev-admin/perseverance-python-buildout/croot/alabaster_1729041938345/work
# altair @ file:///C:/b/abs_0b1avjyzoc/croot/altair_1743016738596/work
# anaconda-anon-usage @ file:///C:/b/abs_1az9wuczyu/croot/anaconda-anon-usage_1749054795139/work
# anaconda-auth @ file:///C:/b/abs_66s84uss7v/croot/anaconda-cloud-auth-split_1747863792543/work
# anaconda-catalogs @ file:///C:/b/abs_ac59ma63va/croot/anaconda-catalogs_1747774731997/work
# anaconda-cli-base @ file:///C:/b/abs_e4_l2p3q_7/croot/anaconda-cli-base_1741369468349/work
# ...

# %% [markdown]
# ## How to install

# %% [markdown]
# - all pip(pip installs packages) commands we can do
#
#        - in jupyter  noatbook
#
#        - in anconda prompt (we called this as terminal)
#
# - Rrcommeneded appraoch is user **terminal**
#
# - while you are installing the packages make sure **internet should be should be connect**
#
# - if you dont connect internet or your internet is weak we will get http error
#
# -the commant aloways starts with : pip install

# %%
import streamlit

# %%
import flask

# %%
import cv2

# %%
pip install opencv-python
# Out:
# ...
#
# ...

# %%
import random

# %%
random.randint(1,10)
# Out:
# 2

# %%
random.random()
# Out:
# 0.8383462801152455

# %%
random.choice(['2','4','6'])
# Out:
# '4'

# %%
random.sample(['red', 'blue'], counts=[4, 2], k=5)
# Out:
# ['red', 'red', 'blue', 'red', 'red']

# %%
t = ['red', 'red', 'blue', 'red', 'red']
random.choice(t)
# Out:
# 'red'

# %%
import math

# %%
math.sqrt(16)
# Out:
# 4.0

# %%
math.pow(5,5)
# Out:
# 3125.0

# %%
math.pow(2,4)
# Out:
# 16.0

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.e
# Out:
# 2.718281828459045

# %%
import time

# %%
time.sleep(5)

# %%
time.time()
# Out:
# 1758260748.0186112

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\shreyansh tiwari\\Documents\\NareshIT\\Python_Session'

# %%
import keyword
dir(keyword)
# Out:
# ['__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'iskeyword',
#  'issoftkeyword',
#  'kwlist',
#  'softkwlist']

# %%
keyword.iskeyword('if')
# Out:
# True

# %%
keyword.iskeyword('abc')
# Out:
# False

# %%
issoftkeyword
